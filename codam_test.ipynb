# %%
# First, we need to install the packages
# !pip install gradio folium pandas

import pandas as pd
import folium
from folium.plugins import MarkerCluster
import gradio as gr
import re, unicodedata, html

# Path to your CSV
CSV_PATH = "kvk_data_codam.csv"

# Static place options you requested
PLAATS_OPTIES = ["Utrecht", "Rotterdam", "Amsterdam", "Eindhoven"]

# Approximate Netherlands bounds (southwest [lat,lon], northeast [lat,lon])
NL_BOUNDS = [[50.75, 3.2], [53.7, 7.22]]
NL_CENTER = [52.1, 5.3]
# Out:
# Requirement already satisfied: gradio in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (5.46.0)
# Requirement already satisfied: folium in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: pandas in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (4.6.2.post1)
# Requirement already satisfied: brotli>=1.1.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.115.5)
# Requirement already satisfied: ffmpy in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.13.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (1.13.0)
# Requirement already satisfied: groovy~=0.1 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.33.5 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.35.0)
# Requirement already satisfied: jinja2<4.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (24.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: pydub in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.13.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.41.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.13.1)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio) (0.32.1)
# Requirement already satisfied: fsspec in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio-client==1.13.0->gradio) (2024.9.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from gradio-client==1.13.0->gradio) (14.1)
# Requirement already satisfied: branca>=0.6.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from folium) (0.8.1)
# Requirement already satisfied: requests in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: idna>=2.8 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: certifi in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from httpx<1.0,>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (3.16.1)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (4.67.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (1.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from pydantic<2.12,>=2.0->gradio) (2.27.0)
# Requirement already satisfied: six>=1.5 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: click>=8.0.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from requests->folium) (1.26.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/bramzijlstra/.pyenv/versions/3.10.10/envs/kvk_main/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
def _squash_ws(text: str) -> str:
    """
    Normalize text for robust searching:
    - Unicode normalize & remove accents
    - Lowercase
    - Collapse multiple whitespace/newlines to a single space
    """
    if not isinstance(text, str):
        text = "" if pd.isna(text) else str(text)
    text = unicodedata.normalize("NFKD", text)
    text = "".join(ch for ch in text if not unicodedata.combining(ch))
    text = text.lower()
    text = re.sub(r"\s+", " ", text).strip()
    return text

def _safe(s):
    """Stringify and HTML-escape to safely show in Folium popups/tooltips."""
    if s is None or (isinstance(s, float) and pd.isna(s)):
        return ""
    return html.escape(str(s))

# %%
def load_data(csv_path=CSV_PATH):
    """Load CSV, coerce lat/lon, clip to NL bounds, create normalized columns."""
    # Handle potential BOM/encoding issues
    try:
        df = pd.read_csv(csv_path)
    except UnicodeDecodeError:
        df = pd.read_csv(csv_path, encoding="utf-8-sig")

    # Ensure numeric lat/lon
    df["lat"] = pd.to_numeric(df.get("lat"), errors="coerce")
    df["lon"] = pd.to_numeric(df.get("lon"), errors="coerce")

    # Keep points roughly within Netherlands
    df = df[
        df["lat"].between(50.5, 54.0) &
        df["lon"].between(2.5, 8.0)
    ].copy()

    # Ensure required columns exist (empty if missing)
    for col in ["Plaats_RechtsPersoon", "Actief", "Bedrijfsomschrijving",
                "HandelsnaamOnderneming", "Rechtsvorm"]:
        if col not in df.columns:
            df[col] = ""

    # Normalize Actief to 'ja'/'nee'
    def _norm_actief(x):
        s = _squash_ws(x)
        return "ja" if s in {"true", "1", "ja", "y", "yes"} else "nee"
    df["Actief_norm"] = df["Actief"].map(_norm_actief)

    # Normalized text column for robust literal substring matching (no regex)
    df["Bedrijfsomschrijving_norm"] = df["Bedrijfsomschrijving"].map(_squash_ws)

    return df

DF = load_data()
DF.shape
# Out:
# (100, 65)

# %%
# 4.1: Peek at the first rows
DF.head(10)
# Out:
#          Id  KVKNummer  VestigingNummer   LaatstGewijzigdTijdstip_MA  \
# 0   1178628   15828107       9867709295  2020-04-28 13:36:07.8710000
# 1  13598565    6451423       3772422261  2022-06-28 13:44:49.0010000
# 2   1973929   51804166       3835681349  2022-05-25 12:16:08.2820000
# 3  11735140   63572655       7265274934  2018-01-09 14:28:02.7950000
# 4  13583448   40644122       7089340237  2019-08-12 11:18:54.0690000
# 5  13918135   13370867       4344308000  2020-10-21 13:38:06.7690000
# 6    639755   94606058       2251818909  2020-01-06 10:56:50.8420000
# 7   7737361   37303637       7884514131  2014-05-07 09:12:48.9990000
# 8    678980   42899343       8289353678  2016-04-18 12:17:05.0940000
# 9   9985800   88017093       1843406482  2014-04-12 06:00:23.8290000
#
#   HoofdNevenVestiging Actief Indicator_Onderneming Indicator_Vestiging  \
# 0      Hoofdvestiging     Ja                    Ja                  Ja
# 1      Hoofdvestiging    Nee                    Ja                  Ja
# 2      Hoofdvestiging     Ja                    Ja                  Ja
# 3      Hoofdvestiging    Nee                    Ja                  Ja
# 4      Hoofdvestiging    Nee                    Ja                  Ja
# 5      Hoofdvestiging    Nee                    Ja                  Ja
# 6      Hoofdvestiging     Ja                    Ja                  Ja
# 7      Hoofdvestiging     Ja                    Ja                  Ja
# 8      Hoofdvestiging    Nee                    Ja                  Ja
# 9      Hoofdvestiging    Nee                    Ja                  Ja
#
#   ImportIndicator ExportIndicator  ... Provincie_RechtsPersoon  \
# 0             Nee             Nee  ...           Noord-Holland
# 1             Nee             Nee  ...           Noord-Brabant
# 2             Nee             Nee  ...           Noord-Brabant
# 3             Nee             Nee  ...            Zuid-Holland
# 4             Nee             Nee  ...           Noord-Holland
# 5             Nee             Nee  ...           Noord-Holland
# 6             Nee             Nee  ...           Noord-Holland
# 7             Nee             Nee  ...           Noord-Holland
# 8             Nee             Nee  ...           Noord-Brabant
# 9             Nee             Nee  ...            Zuid-Holland
#
#    Regio_RechtsPersoon  KrimpGebied_RechtsPersoon  \
# 0            Noordwest                        Nee
# 1                 Zuid                        Nee
# 2                 Zuid                        Nee
# 3             Zuidwest                        Nee
# 4            Noordwest                        Nee
# 5            Noordwest                        Nee
# 6            Noordwest                        Nee
# 7            Noordwest                        Nee
# 8                 Zuid                        Nee
# 9             Zuidwest                        Nee
#
#    AnticipeerGebied_RechtsPersoon  IbisPlanNaam_RechtsPersoon        lat  \
# 0                             Nee        zz - n.v.t./onbekend  52.309344
# 1                             Nee        zz - n.v.t./onbekend  51.450731
# 2                             Nee        zz - n.v.t./onbekend  51.450962
# 3                             Nee        zz - n.v.t./onbekend  51.920720
# 4                             Nee        zz - n.v.t./onbekend  52.318757
# 5                             Nee        zz - n.v.t./onbekend  52.298221
# 6                             Nee        zz - n.v.t./onbekend  52.363716
# 7                             Nee        zz - n.v.t./onbekend  52.358780
# 8                             Nee        zz - n.v.t./onbekend  51.446787
# 9                             Nee        zz - n.v.t./onbekend  51.884337
#
#         lon  Bedrijfsomschrijving  Actief_norm Bedrijfsomschrijving_norm
# 0  4.884548                                 ja
# 1  5.500133                                nee
# 2  5.453899                                 ja
# 3  4.433812                                nee
# 4  4.919727                                nee
# 5  4.740187                                nee
# 6  4.969677                                 ja
# 7  4.832645                                 ja
# 8  5.451773                                nee
# 9  4.517200                                nee
#
# [10 rows x 65 columns]

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Id                                100 non-null    int64
#  1   KVKNummer                         100 non-null    int64
#  2   VestigingNummer                   100 non-null    int64
#  3   LaatstGewijzigdTijdstip_MA        100 non-null    object
#  4   HoofdNevenVestiging               100 non-null    object
#  5   Actief                            100 non-null    object
#  6   Indicator_Onderneming             100 non-null    object
#  7   Indicator_Vestiging               100 non-null    object
#  8   ImportIndicator                   100 non-null    object
#  9   ExportIndicator                   100 non-null    object
#  10  Indicator_Faillissement           100 non-null    object
#  11  ActiviteitCode                    100 non-null    int64
#  12  AanvangDatum_MA                   100 non-null    int64
#  13  EindDatum_MA                      41 non-null     float64
#  14  AanvangDatum_Vest                 100 non-null    int64
#  15  EindDatum_Vest                    44 non-null     float64
#  16  BedrijfsOmschrijving              100 non-null    object
#  17  WPFullTime                        100 non-null    int64
#  18  WPPartTime                        100 non-null    int64
#  19  PersoonType                       100 non-null    object
#  20  NaamNietNatuurlijkPersoon         99 non-null     object
#  21  NaamVestiging                     0 non-null      float64
#  22  RechtsvormCode                    100 non-null    object
#  23  Rechtsvorm                        100 non-null    object
#  24  HandelsnaamVestiging              100 non-null    object
#  25  HandelsnaamOnderneming            100 non-null    object
#  26  DatumUitschrijvingNNP             0 non-null      float64
#  27  NaamNatuurlijkPersoon             1 non-null      object
#  28  NaamMaatschappelijkeActiviteit    100 non-null    object
#  29  ActiviteitNiveau                  57 non-null     object
#  30  AdresType_Vestiging               47 non-null     object
#  31  Postcode_Vestiging                47 non-null     float64
#  32  Plaats_Vestiging                  47 non-null     object
#  33  PostcodeWoonplaats_Vestiging      0 non-null      float64
#  34  LandCode_Vestiging                47 non-null     float64
#  35  Land_Vestiging                    47 non-null     object
#  36  GemeenteCode_Vestiging            47 non-null     float64
#  37  Gemeente_Vestiging                47 non-null     object
#  38  CoropCode_Vestiging               47 non-null     object
#  39  Corop_Vestiging                   47 non-null     object
#  40  Provincie_Vestiging               47 non-null     object
#  41  Regio_Vestiging                   47 non-null     object
#  42  KrimpGebied_Vestiging             47 non-null     object
#  43  AnticipeerGebied_Vestiging        47 non-null     object
#  44  IbisPlanNaam_Vestiging            47 non-null     object
#  45  AdresType_RechtsPersoon           100 non-null    object
#  46  Postcode_RechtsPersoon            100 non-null    int64
#  47  Plaats_RechtsPersoon              100 non-null    object
#  48  PostcodeWoonplaats_RechtsPersoon  0 non-null      float64
#  49  LandCode_RechtsPersoon            100 non-null    int64
#  50  Land_RechtsPersoon                100 non-null    object
#  51  GemeenteCode_RechtsPersoon        100 non-null    int64
#  52  Gemeente_RechtsPersoon            100 non-null    object
#  53  CoropCode_RechtsPersoon           100 non-null    object
#  54  Corop_RechtsPersoon               100 non-null    object
#  55  Provincie_RechtsPersoon           100 non-null    object
#  56  Regio_RechtsPersoon               100 non-null    object
#  57  KrimpGebied_RechtsPersoon         100 non-null    object
#  58  AnticipeerGebied_RechtsPersoon    100 non-null    object
#  59  IbisPlanNaam_RechtsPersoon        100 non-null    object
#  60  lat                               100 non-null    float64
#  61  lon                               100 non-null    float64
#  62  Bedrijfsomschrijving              100 non-null    object
#  63  Actief_norm                       100 non-null    object
#  64  Bedrijfsomschrijving_norm         100 non-null    object
# dtypes: float64(11), int64(11), object(43)
# memory usage: 50.9+ KB

# %%
DF.describe(include="all").T
# Out:
#                             count unique                          top freq  \
# Id                          100.0    NaN                          NaN  NaN
# KVKNummer                   100.0    NaN                          NaN  NaN
# VestigingNummer             100.0    NaN                          NaN  NaN
# LaatstGewijzigdTijdstip_MA    100     99  2010-05-25 23:59:59.9990000    2
# HoofdNevenVestiging           100      2               Hoofdvestiging   95
# ...                           ...    ...                          ...  ...
# lat                         100.0    NaN                          NaN  NaN
# lon                         100.0    NaN                          NaN  NaN
# Bedrijfsomschrijving          100      1                               100
# Actief_norm                   100      2                           ja   56
# Bedrijfsomschrijving_norm     100      1                               100
#
#                                      mean                std         min  \
# Id                             7635941.15     4296150.463496    420833.0
# KVKNummer                     47577290.32    30259395.113832   1160675.0
# VestigingNummer             5026408725.46  2736167873.729667  82123982.0
# LaatstGewijzigdTijdstip_MA            NaN                NaN         NaN
# HoofdNevenVestiging                   NaN                NaN         NaN
# ...                                   ...                ...         ...
# lat                             51.860164           0.350596     51.3818
# lon                              4.921913           0.430968    4.381954
# Bedrijfsomschrijving                  NaN                NaN         NaN
# Actief_norm                           NaN                NaN         NaN
# Bedrijfsomschrijving_norm             NaN                NaN         NaN
#
#                                      25%           50%            75%  \
# Id                             4046099.0     6694229.0     11816137.5
# KVKNummer                    20921116.25    46521353.5    76500972.25
# VestigingNummer             2613874723.5  5208640498.5  7369900639.25
# LaatstGewijzigdTijdstip_MA           NaN           NaN            NaN
# HoofdNevenVestiging                  NaN           NaN            NaN
# ...                                  ...           ...            ...
# lat                            51.477858     51.899791      51.996724
# lon                             4.510329      4.846664       5.425354
# Bedrijfsomschrijving                 NaN           NaN            NaN
# Actief_norm                          NaN           NaN            NaN
# Bedrijfsomschrijving_norm            NaN           NaN            NaN
#
#                                      max
# Id                            14295321.0
# KVKNummer                     99732835.0
# VestigingNummer             9927789931.0
# LaatstGewijzigdTijdstip_MA           NaN
# HoofdNevenVestiging                  NaN
# ...                                  ...
# lat                            52.427778
# lon                             5.525533
# Bedrijfsomschrijving                 NaN
# Actief_norm                          NaN
# Bedrijfsomschrijving_norm            NaN
#
# [65 rows x 11 columns]

# %%
DF["Plaats_RechtsPersoon"].value_counts().loc[PLAATS_OPTIES]
# Out:
# Plaats_RechtsPersoon
# Utrecht       1
# Rotterdam    40
# Amsterdam    24
# Eindhoven    35
# Name: count, dtype: int64

# %%
display(DF["Actief"].value_counts(dropna=False))
display(DF["Actief_norm"].value_counts(dropna=False))
# Out:
# Actief
# Ja     56
# Nee    44
# Name: count, dtype: int64
# Actief_norm
# ja     56
# nee    44
# Name: count, dtype: int64

# %%
def _fit_or_default(m, df):
    """Fit map to filtered points if any, otherwise to NL bounds."""
    if not df.empty:
        coords = df[["lat", "lon"]].dropna().values.tolist()
        if coords:
            m.fit_bounds(coords, padding=(20, 20))
            return
    m.fit_bounds(NL_BOUNDS, padding=(20, 20))

def build_map(plaatsen_selected, actief_selected, omschrijving_query):
    """Create Folium map based on filters, with rich popups."""
    df = DF.copy()

    # Filter: place (multi-select)
    if plaatsen_selected:
        df = df[df["Plaats_RechtsPersoon"].isin(plaatsen_selected)]

    # Filter: active (ja/nee, multi)
    if actief_selected:
        actief_sel_norm = [_squash_ws(s) for s in actief_selected]
        df = df[df["Actief_norm"].isin(actief_sel_norm)]

    # Filter: free-text on normalized description (literal partial match, no regex)
    q = _squash_ws(omschrijving_query or "")
    if q:
        df = df[df["Bedrijfsomschrijving_norm"].str.contains(q, na=False, regex=False)]

    # Build map
    m = folium.Map(
        location=NL_CENTER,
        zoom_start=7,
        tiles="OpenStreetMap",
        max_bounds=True,
        control_scale=True,
        zoom_control=True,
    )

    cluster = MarkerCluster().add_to(m)

    for _, row in df.dropna(subset=["lat", "lon"]).iterrows():
        plaats   = _safe(row.get("Plaats_RechtsPersoon", ""))
        actief   = _safe(row.get("Actief", row.get("Actief_norm", "")))
        naam     = _safe(row.get("HandelsnaamOnderneming", ""))
        rechtsv  = _safe(row.get("Rechtsvorm", ""))
        desc     = _safe(str(row.get("Bedrijfsomschrijving", "")).strip())

        # Tooltip prefers the trade name; falls back to place or generic label
        tooltip_txt = naam if naam else (plaats if plaats else "Location")

        # Rich popup content
        popup_lines = []
        if naam:    popup_lines.append(f"<b>Handelsnaam:</b> {naam}")
        if rechtsv: popup_lines.append(f"<b>Rechtsvorm:</b> {rechtsv}")
        if plaats:  popup_lines.append(f"<b>Plaats:</b> {plaats}")
        if actief:  popup_lines.append(f"<b>Actief:</b> {actief}")
        if desc:    popup_lines.append(f"<b>Omschrijving:</b> {desc}")
        popup_html = "<br>".join(popup_lines) if popup_lines else "No details"

        folium.Marker(
            [row["lat"], row["lon"]],
            tooltip=tooltip_txt,
            popup=folium.Popup(popup_html, max_width=420),
        ).add_to(cluster)

    _fit_or_default(m, df)
    return m._repr_html_()

# %%
# Simple CSS: sticky sidebar + tall map area
CSS = """
#sidebar { position: sticky; top: 0; align-self: flex-start; }
#mapwrap { height: 80vh; }
"""

# Initial HTML for the map (all places, both active states, empty text)
init_html = build_map(
    plaatsen_selected=PLAATS_OPTIES,
    actief_selected=["ja", "nee"],
    omschrijving_query=""
)

with gr.Blocks(title="KVK Map — Places / Active / Description", css=CSS) as demo:
    gr.Markdown("## 🗺️ KVK Map — Filters & Details")

    with gr.Row():
        with gr.Column(scale=1, min_width=280, elem_id="sidebar"):
            plaatsen = gr.CheckboxGroup(
                choices=PLAATS_OPTIES,
                value=PLAATS_OPTIES,
                label="Plaats_RechtsPersoon"
            )
            actief = gr.CheckboxGroup(
                choices=["ja", "nee"],
                value=["ja", "nee"],
                label="Actief"
            )
            omschrijving = gr.Textbox(
                label="Bedrijfsomschrijving (partial, multi-line OK)",
                placeholder="e.g., orthopedie, netwerk, sport..."
            )
            gr.Markdown("Click a marker for **HandelsnaamOnderneming**, **Rechtsvorm**, and more.")

        with gr.Column(scale=3, elem_id="mapwrap"):
            out = gr.HTML(value=init_html)

    # Live interactions (textbox updates on input for instant filtering)
    plaatsen.change(build_map, inputs=[plaatsen, actief, omschrijving], outputs=out)
    actief.change(build_map, inputs=[plaatsen, actief, omschrijving], outputs=out)
    omschrijving.input(build_map, inputs=[plaatsen, actief, omschrijving], outputs=out)

# In notebooks, simply run demo.launch(). In a script, use if __name__ == "__main__".
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
